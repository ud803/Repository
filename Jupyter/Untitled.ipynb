# %%
import re
import pandas as pd


doc = []
with open('dates.txt') as file:
    for line in file:
        doc.append(line)

def date_sorter():
    

    p = re.compile(r'\
(?P<Month>[01]?[0-9]|Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec)[a-z]*[- ,.:/]+\
(?P<Date>[0123]?[0-9])[a-z]*[- ,.:/]+\
(?P<Year>[12]?[09]?[0-9]{2})\
')

    q = re.compile(r'\
(?P<Month>[01]?[0-9]|Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec)[a-z]*[- ,.:/]+\
(?P<Year>[12]?[09]?[0-9]{2})\
')

    r = re.compile(r'\
(?P<Year>[12]?[09]?[0-9]{2})\
')
    
    temp = []
    ptemp = []
    qtemp = []
    rtemp = []
    for i in range(500) :
        ptemp.append(-1)
        qtemp.append(-1)
        rtemp.append(-1)

    for i in range(500) :
        if(p.search(doc[i])) :
            ptemp[i] = p.findall(doc[i])
            
    for i in range(500) :
        if(q.search(doc[i])) :
            qtemp[i] = q.findall(doc[i])
    for i in range(500) :
        if(r.search(doc[i])) :
            rtemp[i] = r.findall(doc[i])
    

    indexl = []
    for i in range(500) :
        indexl.append(0)

    for i in range(500) :
        if(ptemp[i] != -1) :
            indexl[i] = ptemp[i]
    for i in range(500) :
        if(qtemp[i] != -1) :
            if(indexl[i]==0):
                indexl[i] = qtemp[i]
    for i in range(500) :
        if(rtemp[i] != -1) :
            if(indexl[i]==0):
                indexl[i] = rtemp[i]

    real = []
    
    
    for item in indexl :
        if(len(item[0]) !=4) :
            real.append(list(item[0]))
        else :
            real.append(item)

    for i in range(500):
        real[i].append("s{0}".format(i))

    
    
    num1 = []
    num2 = []
    num3 = []

    for item in real :
        if (len(item) == 2) :
            num1.append(item)
        elif (len(item) ==3) :
            num2.append(item)
        elif (len(item) ==4) :
            num3.append(item)


    for item in num1 :
        temp = item[0]
        item.append('1')
        item.append('1')
        item[0], item[2] = item[2], item[0]
        item[1], item[3] = item[3], item[1]

    dictt = {'Jan' :'1', 'Feb' :'2', 'Mar':'3', 'Apr':'4', 'May':'5', 'Jun':'6', 'Jul':'7',\
            'Aug':'8', 'Sep':'9', 'Oct':'10', 'Nov':'11', 'Dec':'12'}

    for i in range(len(num2)) :
        if(num2[i][0].isalpha()) :
            num2[i][0] = dictt[num2[i][0]]
    for i in range(len(num2)) :
        if(num2[i][0].startswith('0')) :
            num2[i][0] = num2[i][0][1:]
        num2[i].insert(1,'1')


    for i in range(len(num3)) :
        if(num3[i][0].isalpha()) :
            num3[i][0] = dictt[num3[i][0]]
    for i in range(len(num3)) :
        if(len(num3[i][2]) !=4) :
            num3[i][2] = '19' + num3[i][2]
    for i in range(len(num3)) :
        if(num3[i][0].startswith('0')) :
            num3[i][0] = num3[i][0][1:]
        if(num3[i][1].startswith('0')) :
            num3[i][1] = num3[i][1][1:]

    for i in range(500) :
        if( real[i][0].isdigit() and real[i][1].isdigit() and real[i][2].isdigit() ) :
            real[i][0] = int(real[i][0])
            real[i][1] = int(real[i][1])
            real[i][2] = int(real[i][2])
        else :
            real[i][0], real[i][1], real[i][2] = 1, 1, 2000

    real = sorted(real, key= lambda x: (x[2], x[0], x[1]))

    for i in range(500) :
        real[i].append(i)
    answer =[]
    real2 = sorted(real, key = lambda x: (int(x[3][1:])))
    for i in range(500) :
        answer.append(real2[i][-1])
        print(answer[i])
    answer2 = pd.Series(answer)
    return answer2
# Out:
# 278
# 178
# 13
# 66
# 316
# 108
# 9
# 235
# 188
# 11
# 176
# 7
# 59
# 336
# 18
# 243
# 459
# 139
# 78
# 10
# 87
# 334
# 113
# 241
# 71
# 168
# 140
# 234
# 76
# 15
# 198
# 174
# 23
# 205
# 254
# 470
# 158
# 29
# 216
# 193
# 126
# 61
# 207
# 294
# 378
# 144
# 330
# 257
# 291
# 171
# 57
# 67
# 253
# 266
# 14
# 201
# 211
# 303
# 36
# 456
# 145
# 307
# 162
# 264
# 208
# 293
# 100
# 259
# 256
# 204
# 184
# 143
# 225
# 90
# 45
# 136
# 111
# 213
# 342
# 118
# 337
# 130
# 99
# 50
# 364
# 12
# 133
# 281
# 324
# 150
# 232
# 312
# 252
# 394
# 77
# 249
# 44
# 192
# 251
# 20
# 166
# 269
# 326
# 381
# 146
# 39
# 97
# 412
# 163
# 47
# 464
# 306
# 21
# 147
# 274
# 328
# 224
# 212
# 88
# 413
# 268
# 340
# 320
# 248
# 86
# 317
# 366
# 401
# 141
# 379
# 19
# 210
# 318
# 427
# 290
# 124
# 183
# 173
# 154
# 263
# 474
# 300
# 494
# 314
# 271
# 389
# 351
# 402
# 368
# 95
# 233
# 116
# 244
# 489
# 16
# 40
# 54
# 46
# 239
# 360
# 369
# 426
# 497
# 41
# 285
# 101
# 62
# 321
# 112
# 195
# 310
# 457
# 24
# 282
# 417
# 220
# 165
# 450
# 237
# 177
# 149
# 221
# 308
# 48
# 434
# 383
# 181
# 498
# 431
# 392
# 91
# 361
# 25
# 280
# 297
# 242
# 371
# 289
# 127
# 482
# 186
# 98
# 352
# 227
# 309
# 73
# 153
# 246
# 400
# 472
# 161
# 231
# 265
# 348
# 323
# 53
# 134
# 219
# 463
# 226
# 69
# 471
# 123
# 332
# 55
# 335
# 22
# 250
# 465
# 182
# 462
# 190
# 495
# 89
# 245
# 386
# 491
# 304
# 70
# 298
# 96
# 460
# 395
# 454
# 473
# 477
# 247
# 131
# 160
# 353
# 279
# 407
# 339
# 418
# 493
# 109
# 485
# 217
